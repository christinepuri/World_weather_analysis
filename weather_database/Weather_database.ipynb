# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
#Create a set of 2,000 random latitudes and longitudes.
lat = np.random.uniform(-90,90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lat, lngs)
coordinates = list(lat_lngs)

# %%
# Import citipy module 
from citipy import citipy

# Create a list for holding the cities. 
cities = []

#Get the nearest city 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
     # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

from config import final_api_key

# %%
#Perform an API call with openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" +final_api_key
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -69.3632, 'lat': 77.484},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 268.27,
#   'feels_like': 264.4,
#   'temp_min': 268.27,
#   'temp_max': 268.27,
#   'pressure': 1021,
#   'humidity': 65,
#   'sea_level': 1021,
#   'grnd_level': 1017},
#  'visibility': 10000,
#  'wind': {'speed': 2.46, 'deg': 25, 'gust': 2.6},
#  'clouds': {'all': 75},
#  'dt': 1631223431,
#  'sys': {'country': 'GL', 'sunrise': 1631176894, 'sunset': 1631233691},
#  'timezone': -10800,
#  'id': 3831208,
#  'name': 'Qaanaaq',
#  'cod': 200}

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | ulladulla
# Processing Record 3 of Set 1 | san juan
# Processing Record 4 of Set 1 | shakiso
# Processing Record 5 of Set 1 | tevaitoa
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | am timan
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | hastings
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | gornopravdinsk
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | ahipara
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | kamenka
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | berlevag
# Processing Record 31 of Set 1 | uglegorsk
# Processing Record 32 of Set 1 | doba
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | blagoyevo
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | manicore
# Processing Record 37 of Set 1 | mahroni
# Processing Record 38 of Set 1 | cayenne
# Processing Record 39 of Set 1 | mahaicony
# City not found. Skipping...
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | shitkino
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | salisbury
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | kolyshley
# Processing Record 49 of Set 1 | dhidhdhoo
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | kupang
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | vanimo
# Processing Record 4 of Set 2 | yelyzavethradka
# Processing Record 5 of Set 2 | santa rosa
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | zhuhai
# Processing Record 10 of Set 2 | atar
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 2 | berdigestyakh
# Processing Record 15 of Set 2 | suhbaatar
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | pasighat
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | tiznit
# Processing Record 21 of Set 2 | koumac
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | harper
# Processing Record 24 of Set 2 | tsuyama
# Processing Record 25 of Set 2 | solnechnyy
# Processing Record 26 of Set 2 | namibe
# Processing Record 27 of Set 2 | leh
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | channel-port aux basques
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | fukue
# Processing Record 36 of Set 2 | gwadar
# Processing Record 37 of Set 2 | diamantino
# Processing Record 38 of Set 2 | camana
# Processing Record 39 of Set 2 | harriston
# Processing Record 40 of Set 2 | mabaruma
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | changji
# Processing Record 43 of Set 2 | skibotn
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | saint john
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | raudeberg
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | finnsnes
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | stuttgart
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | chapayevka
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | roald
# Processing Record 9 of Set 3 | renfrew
# Processing Record 10 of Set 3 | axim
# Processing Record 11 of Set 3 | sola
# Processing Record 12 of Set 3 | gawler
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | mangrol
# Processing Record 15 of Set 3 | laguna
# Processing Record 16 of Set 3 | alta floresta
# Processing Record 17 of Set 3 | washim
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | vestmanna
# Processing Record 20 of Set 3 | kavieng
# Processing Record 21 of Set 3 | calvia
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | kousseri
# Processing Record 25 of Set 3 | buraydah
# Processing Record 26 of Set 3 | roma
# Processing Record 27 of Set 3 | aykhal
# Processing Record 28 of Set 3 | xiaoshi
# Processing Record 29 of Set 3 | livingston
# Processing Record 30 of Set 3 | san andres
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | vallenar
# Processing Record 33 of Set 3 | tuatapere
# Processing Record 34 of Set 3 | turiacu
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | belaya gora
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | west wendover
# Processing Record 39 of Set 3 | eureka
# Processing Record 40 of Set 3 | mecca
# Processing Record 41 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | port-gentil
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | doha
# Processing Record 46 of Set 3 | ternate
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | pachmarhi
# Processing Record 49 of Set 3 | vila velha
# Processing Record 50 of Set 3 | port blair
# Processing Record 1 of Set 4 | meulaboh
# Processing Record 2 of Set 4 | burica
# City not found. Skipping...
# Processing Record 3 of Set 4 | iqaluit
# Processing Record 4 of Set 4 | patacamaya
# Processing Record 5 of Set 4 | alyangula
# Processing Record 6 of Set 4 | ewa beach
# Processing Record 7 of Set 4 | ilhabela
# Processing Record 8 of Set 4 | kahului
# Processing Record 9 of Set 4 | namatanai
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | camopi
# Processing Record 12 of Set 4 | linguere
# Processing Record 13 of Set 4 | punta alta
# Processing Record 14 of Set 4 | yerbogachen
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | bemidji
# Processing Record 17 of Set 4 | ponta delgada
# Processing Record 18 of Set 4 | grants pass
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | sierra vista
# Processing Record 21 of Set 4 | miyako
# Processing Record 22 of Set 4 | bilibino
# Processing Record 23 of Set 4 | kalmunai
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | henties bay
# Processing Record 26 of Set 4 | gidam
# Processing Record 27 of Set 4 | bogorodskoye
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | portree
# Processing Record 30 of Set 4 | nanortalik
# Processing Record 31 of Set 4 | hatillo
# Processing Record 32 of Set 4 | anadyr
# Processing Record 33 of Set 4 | guerrero negro
# Processing Record 34 of Set 4 | orhei
# Processing Record 35 of Set 4 | tiarei
# Processing Record 36 of Set 4 | illela
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | severodvinsk
# Processing Record 39 of Set 4 | husavik
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | cherskiy
# Processing Record 42 of Set 4 | santo tomas
# Processing Record 43 of Set 4 | tome-acu
# City not found. Skipping...
# Processing Record 44 of Set 4 | hambantota
# Processing Record 45 of Set 4 | balabac
# Processing Record 46 of Set 4 | kharan
# Processing Record 47 of Set 4 | ushtobe
# Processing Record 48 of Set 4 | pekan
# Processing Record 49 of Set 4 | hammonton
# Processing Record 50 of Set 4 | ilulissat
# Processing Record 1 of Set 5 | asyut
# Processing Record 2 of Set 5 | saint anthony
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | abha
# Processing Record 5 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 5 | houma
# Processing Record 7 of Set 5 | ulundi
# Processing Record 8 of Set 5 | kemi
# Processing Record 9 of Set 5 | trincomalee
# Processing Record 10 of Set 5 | chiredzi
# Processing Record 11 of Set 5 | gorontalo
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | airai
# Processing Record 14 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 15 of Set 5 | shimoda
# Processing Record 16 of Set 5 | vostok
# Processing Record 17 of Set 5 | comodoro rivadavia
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | beloha
# Processing Record 20 of Set 5 | tezu
# Processing Record 21 of Set 5 | pontianak
# Processing Record 22 of Set 5 | saint-georges
# Processing Record 23 of Set 5 | san pedro
# Processing Record 24 of Set 5 | kajaani
# Processing Record 25 of Set 5 | ures
# Processing Record 26 of Set 5 | mezen
# Processing Record 27 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 5 | sakakah
# Processing Record 29 of Set 5 | neiafu
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | knysna
# Processing Record 33 of Set 5 | chivolo
# Processing Record 34 of Set 5 | ajdabiya
# Processing Record 35 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 36 of Set 5 | yalta
# Processing Record 37 of Set 5 | hun
# Processing Record 38 of Set 5 | rio gallegos
# Processing Record 39 of Set 5 | timra
# Processing Record 40 of Set 5 | el alto
# Processing Record 41 of Set 5 | narsaq
# Processing Record 42 of Set 5 | nadym
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | lodingen
# Processing Record 45 of Set 5 | ponta do sol
# Processing Record 46 of Set 5 | san ignacio
# Processing Record 47 of Set 5 | dudinka
# Processing Record 48 of Set 5 | codrington
# Processing Record 49 of Set 5 | poum
# Processing Record 50 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 6 | malkangiri
# Processing Record 2 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 6 | wairoa
# Processing Record 4 of Set 6 | balkhash
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | pacifica
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | lapithos
# Processing Record 9 of Set 6 | acari
# Processing Record 10 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | gigmoto
# Processing Record 14 of Set 6 | baculin
# Processing Record 15 of Set 6 | udachnyy
# Processing Record 16 of Set 6 | havre-saint-pierre
# Processing Record 17 of Set 6 | isangel
# Processing Record 18 of Set 6 | shache
# Processing Record 19 of Set 6 | ola
# Processing Record 20 of Set 6 | brandfort
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 6 | ginda
# Processing Record 24 of Set 6 | ciudad bolivar
# Processing Record 25 of Set 6 | tual
# Processing Record 26 of Set 6 | myitkyina
# Processing Record 27 of Set 6 | sao filipe
# Processing Record 28 of Set 6 | aginskoye
# Processing Record 29 of Set 6 | larsnes
# Processing Record 30 of Set 6 | severo-kurilsk
# Processing Record 31 of Set 6 | bamako
# Processing Record 32 of Set 6 | itoman
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 34 of Set 6 | puksoozero
# Processing Record 35 of Set 6 | huai yot
# Processing Record 36 of Set 6 | youkounkoun
# Processing Record 37 of Set 6 | yeppoon
# Processing Record 38 of Set 6 | adrar
# Processing Record 39 of Set 6 | poco das trincheiras
# Processing Record 40 of Set 6 | salinas
# Processing Record 41 of Set 6 | clyde river
# Processing Record 42 of Set 6 | wilmington
# Processing Record 43 of Set 6 | half moon bay
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 47 of Set 6 | chumikan
# Processing Record 48 of Set 6 | nata
# Processing Record 49 of Set 6 | pacific grove
# Processing Record 50 of Set 6 | shellbrook
# Processing Record 1 of Set 7 | nouakchott
# Processing Record 2 of Set 7 | comarapa
# Processing Record 3 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 7 | mulchen
# Processing Record 5 of Set 7 | havoysund
# Processing Record 6 of Set 7 | mae hong son
# Processing Record 7 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 7 | olafsvik
# Processing Record 9 of Set 7 | beyneu
# Processing Record 10 of Set 7 | peniche
# Processing Record 11 of Set 7 | oktyabrskiy
# Processing Record 12 of Set 7 | margate
# Processing Record 13 of Set 7 | ancud
# Processing Record 14 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 7 | weyburn
# Processing Record 16 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 7 | cumra
# Processing Record 18 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 7 | flinders
# Processing Record 20 of Set 7 | belance
# Processing Record 21 of Set 7 | mayo
# Processing Record 22 of Set 7 | lang son
# Processing Record 23 of Set 7 | masty
# Processing Record 24 of Set 7 | ilebo
# Processing Record 25 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 7 | samarai
# Processing Record 27 of Set 7 | buin
# Processing Record 28 of Set 7 | jumla
# Processing Record 29 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 7 | zapolyarnyy
# Processing Record 31 of Set 7 | lingyuan
# Processing Record 32 of Set 7 | beira
# Processing Record 33 of Set 7 | zyryanskoye
# Processing Record 34 of Set 7 | mathbaria
# Processing Record 35 of Set 7 | leningradskaya
# Processing Record 36 of Set 7 | chokurdakh
# Processing Record 37 of Set 7 | la union
# Processing Record 38 of Set 7 | ishlei
# City not found. Skipping...
# Processing Record 39 of Set 7 | port lincoln
# Processing Record 40 of Set 7 | zarubino
# Processing Record 41 of Set 7 | kilindoni
# Processing Record 42 of Set 7 | lasa
# Processing Record 43 of Set 7 | maniitsoq
# Processing Record 44 of Set 7 | cabrobo
# Processing Record 45 of Set 7 | guanica
# Processing Record 46 of Set 7 | dongsheng
# Processing Record 47 of Set 7 | khani
# Processing Record 48 of Set 7 | te anau
# Processing Record 49 of Set 7 | los llanos de aridane
# Processing Record 50 of Set 7 | kaoma
# Processing Record 1 of Set 8 | cidreira
# Processing Record 2 of Set 8 | shelburne
# Processing Record 3 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 8 | atocha
# Processing Record 5 of Set 8 | damghan
# Processing Record 6 of Set 8 | bethel
# Processing Record 7 of Set 8 | dingle
# Processing Record 8 of Set 8 | victor harbor
# Processing Record 9 of Set 8 | khatanga
# Processing Record 10 of Set 8 | ahtopol
# Processing Record 11 of Set 8 | ust-maya
# Processing Record 12 of Set 8 | komsomolskiy
# Processing Record 13 of Set 8 | rio grande
# Processing Record 14 of Set 8 | gornyak
# Processing Record 15 of Set 8 | cerrito
# Processing Record 16 of Set 8 | itarema
# Processing Record 17 of Set 8 | nouadhibou
# Processing Record 18 of Set 8 | walvis bay
# Processing Record 19 of Set 8 | xining
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | vieste
# Processing Record 22 of Set 8 | mukhen
# Processing Record 23 of Set 8 | coahuayana
# Processing Record 24 of Set 8 | hobyo
# Processing Record 25 of Set 8 | leningradskiy
# Processing Record 26 of Set 8 | varena
# Processing Record 27 of Set 8 | sao joao da barra
# Processing Record 28 of Set 8 | carutapera
# Processing Record 29 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 8 | mackay
# Processing Record 31 of Set 8 | sturgis
# Processing Record 32 of Set 8 | phetchabun
# Processing Record 33 of Set 8 | chandler
# Processing Record 34 of Set 8 | sinnamary
# Processing Record 35 of Set 8 | baindur
# Processing Record 36 of Set 8 | sioux lookout
# Processing Record 37 of Set 8 | alice springs
# Processing Record 38 of Set 8 | riyadh
# Processing Record 39 of Set 8 | fairbanks
# Processing Record 40 of Set 8 | princeton
# Processing Record 41 of Set 8 | pandan niog
# Processing Record 42 of Set 8 | muros
# Processing Record 43 of Set 8 | xianyang
# Processing Record 44 of Set 8 | usinsk
# Processing Record 45 of Set 8 | green river
# Processing Record 46 of Set 8 | portachuelo
# Processing Record 47 of Set 8 | abay
# Processing Record 48 of Set 8 | yakeshi
# Processing Record 49 of Set 8 | liuli
# Processing Record 50 of Set 8 | sitka
# Processing Record 1 of Set 9 | zhigansk
# Processing Record 2 of Set 9 | maridi
# Processing Record 3 of Set 9 | gat
# Processing Record 4 of Set 9 | kokopo
# Processing Record 5 of Set 9 | kutum
# Processing Record 6 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 7 of Set 9 | abnub
# Processing Record 8 of Set 9 | necochea
# Processing Record 9 of Set 9 | aksu
# Processing Record 10 of Set 9 | prince rupert
# Processing Record 11 of Set 9 | gladstone
# Processing Record 12 of Set 9 | vaitape
# Processing Record 13 of Set 9 | evensk
# Processing Record 14 of Set 9 | sisimiut
# Processing Record 15 of Set 9 | victoria
# Processing Record 16 of Set 9 | ostrovnoy
# Processing Record 17 of Set 9 | tonneins
# Processing Record 18 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 9 | alugan
# Processing Record 20 of Set 9 | praia
# Processing Record 21 of Set 9 | rocha
# Processing Record 22 of Set 9 | kodiak
# Processing Record 23 of Set 9 | tilichiki
# Processing Record 24 of Set 9 | saldanha
# Processing Record 25 of Set 9 | port keats
# Processing Record 26 of Set 9 | wanaka
# Processing Record 27 of Set 9 | souillac
# Processing Record 28 of Set 9 | arthur
# Processing Record 29 of Set 9 | shaoguan
# Processing Record 30 of Set 9 | prabumulih
# Processing Record 31 of Set 9 | san quintin
# Processing Record 32 of Set 9 | zyryanovsk
# Processing Record 33 of Set 9 | moose factory
# Processing Record 34 of Set 9 | palmer
# Processing Record 35 of Set 9 | roura
# Processing Record 36 of Set 9 | souris
# Processing Record 37 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 9 | monte aprazivel
# Processing Record 39 of Set 9 | sochi
# Processing Record 40 of Set 9 | niimi
# Processing Record 41 of Set 9 | guangyuan
# Processing Record 42 of Set 9 | magistralnyy
# Processing Record 43 of Set 9 | wajima
# Processing Record 44 of Set 9 | liepaja
# Processing Record 45 of Set 9 | petawawa
# Processing Record 46 of Set 9 | nishihara
# Processing Record 47 of Set 9 | tarauaca
# Processing Record 48 of Set 9 | boatlaname
# City not found. Skipping...
# Processing Record 49 of Set 9 | barahona
# Processing Record 50 of Set 9 | college
# Processing Record 1 of Set 10 | biak
# Processing Record 2 of Set 10 | tagusao
# Processing Record 3 of Set 10 | ekibastuz
# Processing Record 4 of Set 10 | malinovoye ozero
# Processing Record 5 of Set 10 | baruun-urt
# Processing Record 6 of Set 10 | korsor
# Processing Record 7 of Set 10 | kerema
# Processing Record 8 of Set 10 | moron
# Processing Record 9 of Set 10 | santa catarina de tepehuanes
# Processing Record 10 of Set 10 | araouane
# Processing Record 11 of Set 10 | goundam
# Processing Record 12 of Set 10 | saint-denis
# Processing Record 13 of Set 10 | kudahuvadhoo
# Processing Record 14 of Set 10 | pecos
# Processing Record 15 of Set 10 | maria aurora
# Processing Record 16 of Set 10 | kavaratti
# Processing Record 17 of Set 10 | malanje
# Processing Record 18 of Set 10 | wokha
# Processing Record 19 of Set 10 | cottbus
# Processing Record 20 of Set 10 | dunmore town
# Processing Record 21 of Set 10 | pundaguitan
# Processing Record 22 of Set 10 | coihaique
# Processing Record 23 of Set 10 | clonakilty
# Processing Record 24 of Set 10 | kautokeino
# Processing Record 25 of Set 10 | koppang
# Processing Record 26 of Set 10 | maragogi
# Processing Record 27 of Set 10 | cuauhtemoc
# Processing Record 28 of Set 10 | netrakona
# Processing Record 29 of Set 10 | acarau
# Processing Record 30 of Set 10 | tonj
# Processing Record 31 of Set 10 | kashi
# Processing Record 32 of Set 10 | saint-francois
# Processing Record 33 of Set 10 | manuk mangkaw
# Processing Record 34 of Set 10 | high level
# Processing Record 35 of Set 10 | abu zabad
# Processing Record 36 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 10 | camacha
# Processing Record 38 of Set 10 | bubaque
# Processing Record 39 of Set 10 | hamilton
# Processing Record 40 of Set 10 | pochutla
# Processing Record 41 of Set 10 | ambon
# Processing Record 42 of Set 10 | richards bay
# Processing Record 43 of Set 10 | san fernando
# Processing Record 44 of Set 10 | krasnoselkup
# Processing Record 45 of Set 10 | labuhan
# Processing Record 46 of Set 10 | omagh
# Processing Record 47 of Set 10 | mikuni
# Processing Record 48 of Set 10 | vila franca do campo
# Processing Record 49 of Set 10 | lorengau
# Processing Record 50 of Set 10 | vao
# Processing Record 1 of Set 11 | russell
# Processing Record 2 of Set 11 | skjervoy
# Processing Record 3 of Set 11 | darnah
# Processing Record 4 of Set 11 | kenai
# Processing Record 5 of Set 11 | port pirie
# Processing Record 6 of Set 11 | payo
# Processing Record 7 of Set 11 | georgiyevka
# Processing Record 8 of Set 11 | luderitz
# Processing Record 9 of Set 11 | grass valley
# Processing Record 10 of Set 11 | awjilah
# Processing Record 11 of Set 11 | constitucion
# Processing Record 12 of Set 11 | besikduzu
# Processing Record 13 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 11 | calabozo
# Processing Record 15 of Set 11 | savalou
# Processing Record 16 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 11 | pedernales
# Processing Record 18 of Set 11 | isiro
# Processing Record 19 of Set 11 | khon kaen
# Processing Record 20 of Set 11 | sungai siput utara
# City not found. Skipping...
# Processing Record 21 of Set 11 | barroualie
# City not found. Skipping...
# Processing Record 22 of Set 11 | dakar
# Processing Record 23 of Set 11 | mahajanga
# Processing Record 24 of Set 11 | korla
# Processing Record 25 of Set 11 | nemuro
# Processing Record 26 of Set 11 | meridian
# Processing Record 27 of Set 11 | tautira
# Processing Record 28 of Set 11 | bobo dioulasso
# Processing Record 29 of Set 11 | gori
# Processing Record 30 of Set 11 | lata
# Processing Record 31 of Set 11 | vilyuysk
# Processing Record 32 of Set 11 | gizo
# Processing Record 33 of Set 11 | barinas
# Processing Record 34 of Set 11 | huarmey
# Processing Record 35 of Set 11 | ukiah
# Processing Record 36 of Set 11 | broken hill
# Processing Record 37 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 11 | jabinyanah
# Processing Record 39 of Set 11 | macau
# Processing Record 40 of Set 11 | la rioja
# Processing Record 41 of Set 11 | aswan
# Processing Record 42 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 11 | hay river
# Processing Record 44 of Set 11 | yarensk
# Processing Record 45 of Set 11 | suntar
# Processing Record 46 of Set 11 | villiers
# Processing Record 47 of Set 11 | pala
# Processing Record 48 of Set 11 | hualmay
# Processing Record 49 of Set 11 | karpathos
# Processing Record 50 of Set 11 | den helder
# Processing Record 1 of Set 12 | yurla
# Processing Record 2 of Set 12 | kedrovyy
# Processing Record 3 of Set 12 | grindavik
# Processing Record 4 of Set 12 | port hedland
# Processing Record 5 of Set 12 | chabahar
# Processing Record 6 of Set 12 | lac du bonnet
# Processing Record 7 of Set 12 | mareeba
# Processing Record 8 of Set 12 | wum
# Processing Record 9 of Set 12 | saint quentin
# City not found. Skipping...
# Processing Record 10 of Set 12 | storforshei
# Processing Record 11 of Set 12 | beidao
# Processing Record 12 of Set 12 | ipanema
# Processing Record 13 of Set 12 | srivardhan
# Processing Record 14 of Set 12 | honningsvag
# Processing Record 15 of Set 12 | tver
# Processing Record 16 of Set 12 | ust-nera
# Processing Record 17 of Set 12 | isla mujeres
# Processing Record 18 of Set 12 | phuket
# Processing Record 19 of Set 12 | heihe
# Processing Record 20 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 12 | ortigueira
# Processing Record 22 of Set 12 | kargasok
# Processing Record 23 of Set 12 | bandarbeyla
# Processing Record 24 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 12 | mazatlan
# Processing Record 26 of Set 12 | kirakira
# Processing Record 27 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 12 | poronaysk
# Processing Record 29 of Set 12 | brus
# Processing Record 30 of Set 12 | xique-xique
# Processing Record 31 of Set 12 | grand gaube
# Processing Record 32 of Set 12 | gushikawa
# Processing Record 33 of Set 12 | saulkrasti
# Processing Record 34 of Set 12 | alofi
# Processing Record 35 of Set 12 | conde
# Processing Record 36 of Set 12 | elizabeth city
# Processing Record 37 of Set 12 | valparaiso
# Processing Record 38 of Set 12 | giddalur
# Processing Record 39 of Set 12 | caravelas
# Processing Record 40 of Set 12 | karratha
# Processing Record 41 of Set 12 | marawi
# Processing Record 42 of Set 12 | suluq
# Processing Record 43 of Set 12 | grand-santi
# Processing Record 44 of Set 12 | guerrero
# Processing Record 45 of Set 12 | naze
# Processing Record 46 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 47 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 12 | srednekolymsk
# Processing Record 49 of Set 12 | egvekinot
# Processing Record 50 of Set 12 | oistins
# Processing Record 1 of Set 13 | sur
# Processing Record 2 of Set 13 | pisco
# Processing Record 3 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 13 | athabasca
# Processing Record 5 of Set 13 | coruripe
# Processing Record 6 of Set 13 | emba
# Processing Record 7 of Set 13 | porbandar
# Processing Record 8 of Set 13 | tianpeng
# Processing Record 9 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | aquiraz
# Processing Record 11 of Set 13 | ust-ishim
# Processing Record 12 of Set 13 | san policarpo
# Processing Record 13 of Set 13 | mayya
# Processing Record 14 of Set 13 | sudak
# Processing Record 15 of Set 13 | colac
# Processing Record 16 of Set 13 | nicolas bravo
# Processing Record 17 of Set 13 | marystown
# Processing Record 18 of Set 13 | talnakh
# Processing Record 19 of Set 13 | union hidalgo
# Processing Record 20 of Set 13 | izumiotsu
# Processing Record 21 of Set 13 | rosarito
# Processing Record 22 of Set 13 | huazolotitlan
# City not found. Skipping...
# Processing Record 23 of Set 13 | antalaha
# Processing Record 24 of Set 13 | tura
# Processing Record 25 of Set 13 | conakry
# Processing Record 26 of Set 13 | andros town
# Processing Record 27 of Set 13 | waipawa
# Processing Record 28 of Set 13 | salekhard
# Processing Record 29 of Set 13 | rialma
# Processing Record 30 of Set 13 | tunceli
# Processing Record 31 of Set 13 | vicksburg
# Processing Record 32 of Set 13 | lufilufi
# Processing Record 33 of Set 13 | fairview
# Processing Record 34 of Set 13 | antsohihy
# Processing Record 35 of Set 13 | kaihua
# Processing Record 36 of Set 13 | omboue
# Processing Record 37 of Set 13 | emerald
# Processing Record 38 of Set 13 | nyurba
# Processing Record 39 of Set 13 | road town
# Processing Record 40 of Set 13 | lundazi
# Processing Record 41 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 13 | marevo
# Processing Record 43 of Set 13 | ambikapur
# Processing Record 44 of Set 13 | opuwo
# Processing Record 45 of Set 13 | yangjiang
# Processing Record 46 of Set 13 | kushiro
# Processing Record 47 of Set 13 | linxia
# Processing Record 48 of Set 13 | kungurtug
# Processing Record 49 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 50 of Set 13 | barra patuca
# Processing Record 1 of Set 14 | cap-aux-meules
# Processing Record 2 of Set 14 | guadalupe y calvo
# Processing Record 3 of Set 14 | tigil
# Processing Record 4 of Set 14 | kurilsk
# Processing Record 5 of Set 14 | vestmannaeyjar
# Processing Record 6 of Set 14 | viedma
# Processing Record 7 of Set 14 | luganville
# Processing Record 8 of Set 14 | mishan
# Processing Record 9 of Set 14 | cartagena
# Processing Record 10 of Set 14 | bulgan
# Processing Record 11 of Set 14 | mahibadhoo
# Processing Record 12 of Set 14 | santa lucia
# Processing Record 13 of Set 14 | bayir
# Processing Record 14 of Set 14 | port macquarie
# Processing Record 15 of Set 14 | coos bay
# Processing Record 16 of Set 14 | oranjemund
# Processing Record 17 of Set 14 | namtsy
# Processing Record 18 of Set 14 | saint-joseph
# Processing Record 19 of Set 14 | kieta
# Processing Record 20 of Set 14 | rochelle
# Processing Record 21 of Set 14 | manaia
# Processing Record 22 of Set 14 | ulkan
# Processing Record 23 of Set 14 | mehamn
# Processing Record 24 of Set 14 | rawson
# Processing Record 25 of Set 14 | lere
# Processing Record 26 of Set 14 | maltahohe
# Processing Record 27 of Set 14 | saint-junien
# Processing Record 28 of Set 14 | dubbo
# Processing Record 29 of Set 14 | kyra
# Processing Record 30 of Set 14 | ko samui
# Processing Record 31 of Set 14 | lucea
# Processing Record 32 of Set 14 | ales
# Processing Record 33 of Set 14 | chicama
# Processing Record 34 of Set 14 | karaton
# Processing Record 35 of Set 14 | westport
# Processing Record 36 of Set 14 | bikaner
# Processing Record 37 of Set 14 | ossora
# Processing Record 38 of Set 14 | morondava
# Processing Record 39 of Set 14 | mirnyy
# Processing Record 40 of Set 14 | bara
# Processing Record 41 of Set 14 | rodrigues alves
# Processing Record 42 of Set 14 | itanhandu
# Processing Record 43 of Set 14 | hovd
# Processing Record 44 of Set 14 | cooma
# Processing Record 45 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 14 | nome
# Processing Record 47 of Set 14 | san rafael del sur
# Processing Record 48 of Set 14 | ust-shonosha
# Processing Record 49 of Set 14 | marienburg
# Processing Record 50 of Set 14 | snasa
# Processing Record 1 of Set 15 | rypefjord
# Processing Record 2 of Set 15 | namwala
# Processing Record 3 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 15 | san rafael
# Processing Record 5 of Set 15 | faya
# Processing Record 6 of Set 15 | shangrao
# Processing Record 7 of Set 15 | lawton
# Processing Record 8 of Set 15 | coquimbo
# Processing Record 9 of Set 15 | kotelnich
# Processing Record 10 of Set 15 | luanda
# Processing Record 11 of Set 15 | vung tau
# Processing Record 12 of Set 15 | mackenzie
# Processing Record 13 of Set 15 | tutoia
# Processing Record 14 of Set 15 | monte azul
# Processing Record 15 of Set 15 | sena madureira
# Processing Record 16 of Set 15 | quatre cocos
# Processing Record 17 of Set 15 | trinidad
# Processing Record 18 of Set 15 | zyryanka
# Processing Record 19 of Set 15 | launceston
# Processing Record 20 of Set 15 | qandala
# Processing Record 21 of Set 15 | chisindia
# Processing Record 22 of Set 15 | plettenberg bay
# Processing Record 23 of Set 15 | charters towers
# Processing Record 24 of Set 15 | nabire
# Processing Record 25 of Set 15 | nantucket
# Processing Record 26 of Set 15 | lisala
# Processing Record 27 of Set 15 | akdepe
# Processing Record 28 of Set 15 | guarizama
# Processing Record 29 of Set 15 | kinsale
# Processing Record 30 of Set 15 | mahanje
# Processing Record 31 of Set 15 | iberia
# Processing Record 32 of Set 15 | gopalganj
# Processing Record 33 of Set 15 | verkhoyansk
# Processing Record 34 of Set 15 | koulikoro
# Processing Record 35 of Set 15 | ixtapa
# Processing Record 36 of Set 15 | yanji
# Processing Record 37 of Set 15 | morropon
# Processing Record 38 of Set 15 | cavalcante
# Processing Record 39 of Set 15 | tocopilla
# Processing Record 40 of Set 15 | nauta
# Processing Record 41 of Set 15 | zhanatas
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0     Busselton -33.6500  115.3333     46.09           clear sky        80
# 1     Ulladulla -35.3500  150.4667     65.88          few clouds        71
# 2      San Juan -31.5375  -68.5364     74.73    scattered clouds        25
# 3       Shakiso   5.7500   38.9167     54.10    scattered clouds        92
# 4      Tevaitoa -16.7833 -151.5000     77.34       broken clouds        76
# ..          ...      ...       ...       ...                 ...       ...
# 680       Yanji  42.9075  129.5078     60.80       broken clouds        95
# 681    Morropon  -5.1822  -79.9689     89.01          few clouds        39
# 682  Cavalcante -13.7975  -47.4583     81.57           clear sky        21
# 683   Tocopilla -22.0920  -70.1979     63.50          few clouds        65
# 684       Nauta  -4.5061  -73.5757     82.85       broken clouds        71
#
#      Cloudiness  Wind Speed Country
# 0             9        0.65      AU
# 1            21        9.19      AU
# 2            49        3.29      AR
# 3            37        3.65      ET
# 4            67       19.17      PF
# ..          ...         ...     ...
# 680          78        1.28      CN
# 681          21       14.18      PE
# 682           2        2.57      BR
# 683          18        4.68      CL
# 684          54        2.21      PE
#
# [685 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     46.09        80           9
# 1     Ulladulla      AU -35.3500  150.4667     65.88        71          21
# 2      San Juan      AR -31.5375  -68.5364     74.73        25          49
# 3       Shakiso      ET   5.7500   38.9167     54.10        92          37
# 4      Tevaitoa      PF -16.7833 -151.5000     77.34        76          67
# 5        Faanui      PF -16.4833 -151.7500     77.63        78          38
# 6       Rikitea      PF -23.1203 -134.9692     73.49        82          60
# 7  Puerto Ayora      EC  -0.7393  -90.3518     76.96        87          71
# 8     Hithadhoo      MV  -0.6000   73.0833     82.92        72           9
# 9         Tiksi      RU  71.6872  128.8694     41.77        61          99
#
#    Wind Speed Current Description
# 0        0.65           clear sky
# 1        9.19          few clouds
# 2        3.29    scattered clouds
# 3        3.65    scattered clouds
# 4       19.17       broken clouds
# 5       18.34       moderate rain
# 6       23.71       moderate rain
# 7       11.01       broken clouds
# 8       10.31           clear sky
# 9        6.91     overcast clouds

# %%
# Export the City_Data into a CSV.
output_data_file = "weather_database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index = "City ID")
